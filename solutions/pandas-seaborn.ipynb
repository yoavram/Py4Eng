# %% [markdown]
# ## Exercise: data frames
# ### 1

# %%
reptiles = (data['Class'] == 'Reptilia').sum()
pythons = (data['Genus'] == 'Python').sum()

# %% [markdown]
# ### 2

# %%
is_mammal = data['Class'] == 'Mammalia'
assert is_mammal.any()
mammals_mass = data.loc[is_mammal, 'Body mass (kg)']
mammals_mass.plot.hist(bins=100, cumulative=True)
plt.xlabel('Mammal body mass (kg)');

# %% [markdown]
# ## Exercise: boxplot

# %%
sns.boxplot(y='Order', x='Body mass (kg)', data=abund_mammalia, orient='h')
plt.xscale('log');
