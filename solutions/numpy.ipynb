# %% [markdown]
# # NumPy
#
# ## Exercise 1

# %%
print(data[-1, -1])
print(data[-1, :])
print(data[:, -1])

# %% [markdown]
# ## Exercise 2

# %%
sqrt = np.sqrt(data[:3, :5])
print(sqrt)

# %% [markdown]
# ## Exercise 3

# %%
print(data.argmax(axis=1))

# %% [markdown]
# ## Exercise 4

# %%
print(1/np.arange(2, 101, 2))

# %% [markdown]
# ## Exercise 5

# %%
print(np.eye(3, dtype=int).ravel())

# %% [markdown]
# ## Exercise 6
# 1)

# %%
print(np.random.geometric(p=0.1, size=(4, 5, 6)))

# %% [markdown]
# 2)

# %%
Z -= Z.min()
Z /= Z.max()
print(Z)

# %% [markdown]
# ## Exercise 7

# %%
D = X.reshape((-1, 1)) - X

# %% [markdown]
# ## Exercise 8

# %%
mask = (Z >= 3) & (Z <= 8)
Z[mask] *= -1
print(Z)
