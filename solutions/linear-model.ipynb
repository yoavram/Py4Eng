# %%
import urllib.request
import zipfile
import os.path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats

# %%
fname = '../data/anage_data.txt'
df = pd.read_csv(fname, sep='\t')
df.head()
# Out:
#    HAGRID   Kingdom      Phylum         Class        Order         Family  \
# 0       3  Animalia  Arthropoda  Branchiopoda  Diplostraca     Daphniidae
# 1       5  Animalia  Arthropoda       Insecta      Diptera  Drosophilidae
# 2       6  Animalia  Arthropoda       Insecta  Hymenoptera         Apidae
# 3       8  Animalia  Arthropoda       Insecta  Hymenoptera     Formicidae
# 4       9  Animalia  Arthropoda       Insecta  Hymenoptera     Formicidae
#
#            Genus       Species              Common name  \
# 0        Daphnia     pulicaria                  Daphnia
# 1     Drosophila  melanogaster                Fruit fly
# 2           Apis     mellifera                Honey bee
# 3  Cardiocondyla     obscurior  Cardiocondyla obscurior
# 4         Lasius         niger         Black garden ant
#
#    Female maturity (days)  ...  Source  Specimen origin  Sample size  \
# 0                     NaN  ...     NaN          unknown       medium
# 1                     7.0  ...     NaN        captivity        large
# 2                     NaN  ...     812          unknown       medium
# 3                     NaN  ...    1293        captivity       medium
# 4                     NaN  ...     411          unknown       medium
#
#    Data quality  IMR (per yr)  MRDT (yrs)  Metabolic rate (W)  Body mass (g)  \
# 0    acceptable           NaN         NaN                 NaN            NaN
# 1    acceptable          0.05        0.04                 NaN            NaN
# 2    acceptable           NaN         NaN                 NaN            NaN
# 3    acceptable           NaN         NaN                 NaN            NaN
# 4    acceptable           NaN         NaN                 NaN            NaN
#
#    Temperature (K)                                         References
# 0              NaN                                     1294,1295,1296
# 1              NaN  2,20,32,47,53,68,69,240,241,242,243,274,602,98...
# 2              NaN  63,407,408,741,805,806,808,812,815,828,830,831...
# 3              NaN                                               1293
# 4              NaN                                        411,813,814
#
# [5 rows x 31 columns]

# %%
df = df[df['Body mass (g)'] < 3e5]
df['Body mass ^ 3/4'] = df['Body mass (g)'] ** (3/4)
df.head()
# Out:
#     HAGRID   Kingdom    Phylum     Class  Order     Family       Genus  \
# 11      18  Animalia  Chordata  Amphibia  Anura  Bufonidae    Anaxyrus
# 19      26  Animalia  Chordata  Amphibia  Anura  Bufonidae    Anaxyrus
# 29      36  Animalia  Chordata  Amphibia  Anura  Bufonidae    Rhinella
# 53      60  Animalia  Chordata  Amphibia  Anura    Hylidae        Hyla
# 60      67  Animalia  Chordata  Amphibia  Anura    Hylidae  Pseudacris
#
#        Species    Common name  Female maturity (days)  ...  Specimen origin  \
# 11  americanus  American toad                   910.0  ...        captivity
# 19  terrestris  Southern toad                     NaN  ...        captivity
# 29      marina      Cane toad                   365.0  ...        captivity
# 53  versicolor  Gray treefrog                   730.0  ...        captivity
# 60    crucifer  Spring peeper                   912.0  ...          unknown
#
#     Sample size  Data quality  IMR (per yr)  MRDT (yrs)  Metabolic rate (W)  \
# 11       medium    acceptable           NaN         NaN             0.00829
# 19       medium    acceptable           NaN         NaN             0.00698
# 29        large    acceptable           NaN         NaN             0.03030
# 53       medium    acceptable           NaN         NaN             0.00433
# 60        small           low           NaN         NaN             0.00105
#
#     Body mass (g)  Temperature (K)          References  Body mass ^ 3/4
# 11          21.60            288.0  37,268,426,525,749        10.019368
# 19          19.20            288.0          37,451,749         9.172251
# 29         105.00            293.0      37,296,485,749        32.801369
# 53           6.97            290.5      37,528,543,749         4.289677
# 60           0.90            292.0  37,451,525,528,749         0.924021
#
# [5 rows x 32 columns]

# %%
sns.regplot(x='Body mass ^ 3/4', y='Metabolic rate (W)', data=df);

# %%
sns.lmplot(x='Body mass ^ 3/4', y='Metabolic rate (W)', hue='Class', data=df, col='Class', 
    sharex=False, sharey=False, scatter_kws=dict(alpha=0.3));

# %%
print('Linear regression:')
for clazz, grp in df.groupby('Class'):
    res = scipy.stats.linregress(grp['Body mass ^ 3/4'], grp['Metabolic rate (W)'])
    print("{:s}: W = {:.2g} * g + {:.2g}".format(clazz, res.slope, res.intercept))
# Out:
# Linear regression:
# Amphibia: W = 0.00029 * g + 0.0037
# Aves: W = 0.013 * g + 0.66
# Mammalia: W = 0.02 * g + -0.53
# Reptilia: W = 0.0011 * g + -0.021
