# %% [markdown]
# ![Py4Eng](img/logo.png)
#
# # Conda virtual environments
# ## Yoav Ram

# %% [markdown]
# We know that conda is a package manager. But conda is also an [environment manager](http://conda.pydata.org/docs/using/envs.html).
#
# A conda environment is a directory (usually inside the `Anaconda` folder) that contains a specific collection of conda packages that you have installed - this includes a specific Python version.
# For example, you may have one environment with NumPy 1.7 and its dependencies,
# and another environment with NumPy 1.6 for legacy testing.
# If you change one environment, your other environments are not affected.
# You can easily switch between these environments.
# You can also share your environment with someone by giving them a copy of an `environment.yml` file.
#
# Environments are very useful:
#
# - Testing code with different Python and package versions
# - Trying new packages without polluting our root environment (including new Python versions)
# - Separating projects with different dependencies: old project can go on using old version of package, new project can use new version, even if it's not backward compatible.
# - Reproducing someone elses exact environment
#
# # Example
#
# Right now we are working with the *root* environment, which was probably installed with Python 3.6 (March 2017).
# Let's create a new environment with Python 2.7 and install NumPy, SciPy, and Matplotlib.
#
# We start by updating conda itself:

# %%
# !conda update -y -q conda
# Out:
# Fetching package metadata ...........
# Solving package specifications: ..........
#
# # All requested packages already installed.
# # packages in environment at /Users/yoavram/miniconda3:
# #
# conda                     4.2.13                   py35_0    conda-forge

# %% [markdown]
# Next, we create a new environment called `python27` and ask conda to install Python 2.7, NumPy, SciPy, and Matplotlib. This could take a while as conda will probably download all these packages from the web, unless you've already downloaded them in the past (conda keeps a cache of previous downloads).

# %%
# !conda create -y -q -n python27 python=2.7 numpy scipy matplotlib
# Out:
# Fetching package metadata ...........
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/yoavram/miniconda3/envs/python27:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyparsing-2.2.0            |           py27_0          92 KB  conda-forge
#     scipy-0.19.0               |np112py27_blas_openblas_200        15.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        15.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     backports_abc:      0.5-py27_0                         conda-forge
#     blas:               1.1-openblas                       conda-forge
#     ca-certificates:    2017.1.23-0                        conda-forge
#     certifi:            2017.1.23-py27_0                   conda-forge
#     cycler:             0.10.0-py27_0                      conda-forge
#     freetype:           2.7-1                              conda-forge
#     functools32:        3.2.3.2-py27_1                     conda-forge
#     libgfortran:        3.0.0-0                            conda-forge
#     libpng:             1.6.28-0                           conda-forge
#     matplotlib:         2.0.0-np112py27_2                  conda-forge
#     ncurses:            5.9-10                             conda-forge
#     numpy:              1.12.0-py27_blas_openblas_200      conda-forge [blas_openblas]
#     openblas:           0.2.19-1                           conda-forge
#     openssl:            1.0.2h-3                           conda-forge
#     pip:                9.0.1-py27_0                       conda-forge
#     pyparsing:          2.2.0-py27_0                       conda-forge
#     python:             2.7.12-2                           conda-forge
#     python-dateutil:    2.6.0-py27_0                       conda-forge
#     pytz:               2016.10-py27_0                     conda-forge
#     readline:           6.2-0                              conda-forge
#     scipy:              0.19.0-np112py27_blas_openblas_200 conda-forge [blas_openblas]
#     setuptools:         33.1.0-py27_0                      conda-forge
#     singledispatch:     3.4.0.3-py27_0                     conda-forge
#     six:                1.10.0-py27_1                      conda-forge
#     sqlite:             3.13.0-1                           conda-forge
#     ssl_match_hostname: 3.5.0.1-py27_1                     conda-forge
#     subprocess32:       3.2.7-py27_0                       conda-forge
#     tk:                 8.5.19-1                           conda-forge
#     tornado:            4.4.2-py27_0                       conda-forge
#     wheel:              0.29.0-py27_0                      conda-forge
#     zlib:               1.2.11-0                           conda-forge
#
# #
# # To activate this environment, use:
# # > source activate python27
# #
# # To deactivate this environment, use:
# # > source deactivate python27
# #

# %% [markdown]
# OK, conda suggest we activate this environment - that is, switch to it. This would work great in the terminal, but not in the notebook, as every `!` command uses a new console. To switch back to the *root* environment you can type `deactivate`.
#
# We will need to install *ipykernel* which will allow us to use this new environment in the notebook.

# %%
# !conda install -y -q -n python27 ipykernel
# Out:
# Fetching package metadata ...........
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/yoavram/miniconda3/envs/python27:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.0              |           py27_0           6 KB  conda-forge
#     backports.shutil_get_terminal_size-1.0.0|           py27_1           7 KB  conda-forge
#     decorator-4.0.11           |           py27_0          13 KB  conda-forge
#     enum34-1.1.6               |           py27_1          54 KB  conda-forge
#     ipython_genutils-0.1.0     |           py27_0          33 KB  conda-forge
#     ptyprocess-0.5.1           |           py27_0          19 KB  conda-forge
#     pyzmq-16.0.2               |           py27_1         381 KB  conda-forge
#     scandir-1.5                |           py27_1          24 KB  conda-forge
#     simplegeneric-0.8.1        |           py27_0           6 KB  conda-forge
#     wcwidth-0.1.7              |           py27_0          22 KB  conda-forge
#     pathlib2-2.2.1             |           py27_0          29 KB  conda-forge
#     pexpect-4.2.1              |           py27_0          67 KB  conda-forge
#     traitlets-4.3.1            |           py27_0         122 KB  conda-forge
#     jupyter_core-4.3.0         |           py27_0          60 KB  conda-forge
#     pickleshare-0.7.3          |           py27_0           9 KB  conda-forge
#     jupyter_client-5.0.0       |           py27_0         116 KB  conda-forge
#     prompt_toolkit-1.0.13      |           py27_0         332 KB  conda-forge
#     ipython-5.3.0              |           py27_0        1015 KB  conda-forge
#     ipykernel-4.5.2            |           py27_0         130 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#     appnope:                            0.1.0-py27_0  conda-forge
#     backports.shutil_get_terminal_size: 1.0.0-py27_1  conda-forge
#     decorator:                          4.0.11-py27_0 conda-forge
#     enum34:                             1.1.6-py27_1  conda-forge
#     ipykernel:                          4.5.2-py27_0  conda-forge
#     ipython:                            5.3.0-py27_0  conda-forge
#     ipython_genutils:                   0.1.0-py27_0  conda-forge
#     jupyter_client:                     5.0.0-py27_0  conda-forge
#     jupyter_core:                       4.3.0-py27_0  conda-forge
#     libsodium:                          1.0.10-0      conda-forge
#     pathlib2:                           2.2.1-py27_0  conda-forge
#     pexpect:                            4.2.1-py27_0  conda-forge
#     pickleshare:                        0.7.3-py27_0  conda-forge
#     prompt_toolkit:                     1.0.13-py27_0 conda-forge
#     ptyprocess:                         0.5.1-py27_0  conda-forge
#     pygments:                           2.2.0-py27_0  conda-forge
#     pyzmq:                              16.0.2-py27_1 conda-forge
#     scandir:                            1.5-py27_1    conda-forge
#     simplegeneric:                      0.8.1-py27_0  conda-forge
#     traitlets:                          4.3.1-py27_0  conda-forge
#     wcwidth:                            0.1.7-py27_0  conda-forge
#     zeromq:                             4.2.1-1       conda-forge

# %% [markdown]
# You can now change the kernel to *Python27* in the top menu `Kernel -> Change kernel`. You might need to refresh the browser first.
#
# Let's check the Python version:

# %%
import sys
sys.version
# Out:
# '2.7.12 | packaged by conda-forge | (default, Feb 10 2017, 07:08:51) \n[GCC 4.2.1 Compatible Apple LLVM 7.3.0 (clang-703.0.31)]'

# %% [markdown]
# Finally, we can install additional packages, such as Searborn:

# %%
# !conda install -y -q -n python27 seaborn
# Out:
# Fetching package metadata ...........
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/yoavram/miniconda3/envs/python27:
#
# The following NEW packages will be INSTALLED:
#
#     pandas:      0.19.2-np112py27_1 conda-forge
#     patsy:       0.4.1-py27_0       conda-forge
#     seaborn:     0.7.1-py27_0       conda-forge
#     statsmodels: 0.8.0-np112py27_0  conda-forge

# %% [markdown]
# Let's install a specific version of Scikit-learn; we can search versions and builds using `conda search`:

# %%
# !conda search scikit-learn
# Out:
# Fetching package metadata ...........
# scikit-learn                 0.11                 np15py26_0  defaults
#                              0.11                 np15py27_0  defaults
#                              0.11                 np16py26_0  defaults
#                              0.11                 np16py27_0  defaults
#                              0.11                 np17py26_0  defaults
#                              0.11                 np17py27_0  defaults
#                              0.12.1               np15py26_0  defaults
#                              0.12.1               np15py27_0  defaults
#                              0.12.1               np16py26_0  defaults
#                              0.12.1               np16py27_0  defaults
#                              0.12.1               np17py26_0  defaults
#                              0.12.1               np17py27_0  defaults
#                              0.13                 np15py26_0  defaults
#                              0.13                 np15py27_0  defaults
#                              0.13                 np16py26_0  defaults
#                              0.13                 np16py27_0  defaults
#                              0.13                 np17py26_0  defaults
#                              0.13                 np17py27_0  defaults
#                              0.13.1               np15py26_0  defaults
#                              0.13.1              np15py26_p0  defaults        [mkl]
#                              0.13.1               np15py27_0  defaults
#                              0.13.1              np15py27_p0  defaults        [mkl]
#                              0.13.1               np16py26_0  defaults
#                              0.13.1              np16py26_p0  defaults        [mkl]
#                              0.13.1               np16py27_0  defaults
#                              0.13.1              np16py27_p0  defaults        [mkl]
#                              0.13.1               np17py26_0  defaults
#                              0.13.1              np17py26_p0  defaults        [mkl]
#                              0.13.1               np17py27_0  defaults
#                              0.13.1              np17py27_p0  defaults        [mkl]
#                              0.14.1               np16py26_0  defaults
#                              0.14.1              np16py26_p0  defaults        [mkl]
#                              0.14.1               np16py27_0  defaults
#                              0.14.1              np16py27_p0  defaults        [mkl]
#                              0.14.1               np17py26_0  defaults
#                              0.14.1              np17py26_p0  defaults        [mkl]
#                              0.14.1               np17py27_0  defaults
#                              0.14.1              np17py27_p0  defaults        [mkl]
#                              0.14.1               np17py33_0  defaults
#                              0.14.1               np16py26_1  defaults
#                              0.14.1              np16py26_p1  defaults        [mkl]
#                              0.14.1               np16py27_1  defaults
#                              0.14.1              np16py27_p1  defaults        [mkl]
#                              0.14.1               np17py26_1  defaults
#                              0.14.1              np17py26_p1  defaults        [mkl]
#                              0.14.1               np17py27_1  defaults
#                              0.14.1              np17py27_p1  defaults        [mkl]
#                              0.14.1               np17py33_1  defaults
#                              0.14.1               np18py26_1  defaults
#                              0.14.1              np18py26_p1  defaults        [mkl]
#                              0.14.1               np18py27_1  defaults
#                              0.14.1              np18py27_p1  defaults        [mkl]
#                              0.14.1               np18py33_1  defaults
#                              0.15.0b1             np18py26_0  defaults
#                              0.15.0b1            np18py26_p0  defaults        [mkl]
#                              0.15.0b1             np18py27_0  defaults
#                              0.15.0b1            np18py27_p0  defaults        [mkl]
#                              0.15.0b1             np18py33_0  defaults
#                              0.15.0b1            np18py33_p0  defaults        [mkl]
#                              0.15.0b1             np18py34_0  defaults
#                              0.15.0b1            np18py34_p0  defaults        [mkl]
#                              0.15.0b2             np18py26_0  defaults
#                              0.15.0b2            np18py26_p0  defaults        [mkl]
#                              0.15.0b2             np18py27_0  defaults
#                              0.15.0b2            np18py27_p0  defaults        [mkl]
#                              0.15.0b2             np18py33_0  defaults
#                              0.15.0b2            np18py33_p0  defaults        [mkl]
#                              0.15.0b2             np18py34_0  defaults
#                              0.15.0b2            np18py34_p0  defaults        [mkl]
#                              0.15.0               np18py26_0  defaults
#                              0.15.0              np18py26_p0  defaults        [mkl]
#                              0.15.0               np18py27_0  defaults
#                              0.15.0              np18py27_p0  defaults        [mkl]
#                              0.15.0               np18py33_0  defaults
#                              0.15.0              np18py33_p0  defaults        [mkl]
#                              0.15.0               np18py34_0  defaults
#                              0.15.0              np18py34_p0  defaults        [mkl]
#                              0.15.1               np18py26_0  defaults
#                              0.15.1              np18py26_p0  defaults        [mkl]
#                              0.15.1               np18py27_0  defaults
#                              0.15.1              np18py27_p0  defaults        [mkl]
#                              0.15.1               np18py33_0  defaults
#                              0.15.1              np18py33_p0  defaults        [mkl]
#                              0.15.1               np18py34_0  defaults
#                              0.15.1              np18py34_p0  defaults        [mkl]
#                              0.15.2               np18py26_0  defaults
#                              0.15.2              np18py26_p0  defaults        [mkl]
#                              0.15.2               np18py27_0  defaults
#                              0.15.2              np18py27_p0  defaults        [mkl]
#                              0.15.2               np18py33_0  defaults
#                              0.15.2              np18py33_p0  defaults        [mkl]
#                              0.15.2               np18py34_0  defaults
#                              0.15.2              np18py34_p0  defaults        [mkl]
#                              0.15.2               np19py26_0  defaults
#                              0.15.2              np19py26_p0  defaults        [mkl]
#                              0.15.2               np19py27_0  defaults
#                              0.15.2              np19py27_p0  defaults        [mkl]
#                              0.15.2               np19py33_0  defaults
#                              0.15.2              np19py33_p0  defaults        [mkl]
#                              0.15.2               np19py34_0  defaults
#                              0.15.2              np19py34_p0  defaults        [mkl]
#                              0.16.0               np19py26_0  defaults
#                              0.16.0              np19py26_p0  defaults        [mkl]
#                              0.16.0               np19py27_0  defaults
#                              0.16.0              np19py27_p0  defaults        [mkl]
#                              0.16.0               np19py33_0  defaults
#                              0.16.0              np19py33_p0  defaults        [mkl]
#                              0.16.0               np19py34_0  defaults
#                              0.16.0              np19py34_p0  defaults        [mkl]
#                              0.16.1              np110py27_0  defaults
#                              0.16.1              np110py34_0  defaults
#                              0.16.1              np110py35_0  defaults
#                              0.16.1               np19py26_0  defaults
#                              0.16.1              np19py26_p0  defaults        [mkl]
#                              0.16.1               np19py27_0  defaults
#                              0.16.1              np19py27_p0  defaults        [mkl]
#                              0.16.1               np19py33_0  defaults
#                              0.16.1              np19py33_p0  defaults        [mkl]
#                              0.16.1               np19py34_0  defaults
#                              0.16.1              np19py34_p0  defaults        [mkl]
#                              0.16.1               np19py35_0  defaults
#                              0.17                np110py27_0  defaults
#                              0.17                np110py34_0  defaults
#                              0.17                np110py35_0  defaults
#                              0.17                np110py27_1  defaults
#                              0.17               np110py27_p1  defaults        [mkl]
#                              0.17                np110py34_1  defaults
#                              0.17                np110py35_1  defaults
#                              0.17               np110py35_p1  defaults        [mkl]
#                              0.17                np110py27_2  defaults
#                              0.17            np110py27_nomkl_2  defaults        [nomkl]
#                              0.17                np110py34_2  defaults
#                              0.17            np110py34_nomkl_2  defaults        [nomkl]
#                              0.17                np110py35_2  defaults
#                              0.17            np110py35_nomkl_2  defaults        [nomkl]
#                              0.17.1              np110py27_0  defaults
#                              0.17.1          np110py27_nomkl_0  defaults        [nomkl]
#                              0.17.1              np110py34_0  defaults
#                              0.17.1          np110py34_nomkl_0  defaults        [nomkl]
#                              0.17.1              np110py35_0  defaults
#                              0.17.1          np110py35_nomkl_0  defaults        [nomkl]
#                              0.17.1              np111py27_0  defaults
#                              0.17.1          np111py27_nomkl_0  defaults        [nomkl]
#                              0.17.1              np111py34_0  defaults
#                              0.17.1          np111py34_nomkl_0  defaults        [nomkl]
#                              0.17.1              np111py35_0  defaults
#                              0.17.1          np111py35_nomkl_0  defaults        [nomkl]
#                              0.17.1              np110py27_1  defaults
#                              0.17.1          np110py27_nomkl_1  defaults        [nomkl]
#                              0.17.1              np110py34_1  defaults
#                              0.17.1          np110py34_nomkl_1  defaults        [nomkl]
#                              0.17.1              np110py35_1  defaults
#                              0.17.1          np110py35_nomkl_1  defaults        [nomkl]
#                              0.17.1              np111py27_1  defaults
#                              0.17.1          np111py27_nomkl_1  defaults        [nomkl]
#                              0.17.1              np111py34_1  defaults
#                              0.17.1          np111py34_nomkl_1  defaults        [nomkl]
#                              0.17.1              np111py35_1  defaults
#                              0.17.1          np111py35_nomkl_1  defaults        [nomkl]
#                              0.17.1              np110py27_2  defaults
#                              0.17.1          np110py27_nomkl_2  defaults        [nomkl]
#                              0.17.1              np110py34_2  defaults
#                              0.17.1          np110py34_nomkl_2  defaults        [nomkl]
#                              0.17.1              np110py35_2  defaults
#                              0.17.1          np110py35_nomkl_2  defaults        [nomkl]
#                              0.17.1              np111py27_2  defaults
#                              0.17.1          np111py27_nomkl_2  defaults        [nomkl]
#                              0.17.1              np111py34_2  defaults
#                              0.17.1          np111py34_nomkl_2  defaults        [nomkl]
#                              0.17.1              np111py35_2  defaults
#                              0.17.1          np111py35_nomkl_2  defaults        [nomkl]
#                              0.17.1          np110py27_blas_openblas_200  conda-forge     [blas_openblas]
#                              0.17.1          np110py34_blas_openblas_200  conda-forge     [blas_openblas]
#                              0.17.1          np110py35_blas_openblas_200  conda-forge     [blas_openblas]
#                              0.17.1          np111py27_blas_openblas_200  conda-forge     [blas_openblas]
#                              0.17.1          np111py34_blas_openblas_200  conda-forge     [blas_openblas]
#                              0.17.1          np111py35_blas_openblas_200  conda-forge     [blas_openblas]
#                              0.17.1          np110py27_blas_openblas_201  conda-forge     [blas_openblas]
#                              0.17.1          np110py34_blas_openblas_201  conda-forge     [blas_openblas]
#                              0.17.1          np110py35_blas_openblas_201  conda-forge     [blas_openblas]
#                              0.17.1          np111py27_blas_openblas_201  conda-forge     [blas_openblas]
#                              0.17.1          np111py34_blas_openblas_201  conda-forge     [blas_openblas]
#                              0.17.1          np111py35_blas_openblas_201  conda-forge     [blas_openblas]
#                              0.17.1          np110py27_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.17.1          np110py34_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.17.1          np110py35_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.17.1          np111py27_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.17.1          np111py34_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.17.1          np111py35_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18rc2         np110py27_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18rc2         np110py34_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18rc2         np110py35_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18rc2         np111py27_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18rc2         np111py34_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18rc2         np111py35_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18                np111py27_0  defaults
#                              0.18            np111py27_nomkl_0  defaults        [nomkl]
#                              0.18                np111py34_0  defaults
#                              0.18            np111py34_nomkl_0  defaults        [nomkl]
#                              0.18                np111py35_0  defaults
#                              0.18            np111py35_nomkl_0  defaults        [nomkl]
#                              0.18            np110py27_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18            np110py34_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18            np110py35_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18            np111py27_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18            np111py34_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18            np111py35_blas_openblas_202  conda-forge     [blas_openblas]
#                              0.18            np110py27_blas_openblas_203  conda-forge     [blas_openblas]
#                              0.18            np110py34_blas_openblas_203  conda-forge     [blas_openblas]
#                              0.18            np110py35_blas_openblas_203  conda-forge     [blas_openblas]
#                              0.18            np111py27_blas_openblas_203  conda-forge     [blas_openblas]
#                           .  0.18            np111py34_blas_openblas_203  conda-forge     [blas_openblas]
#                           .  0.18            np111py35_blas_openblas_203  conda-forge     [blas_openblas]
#                              0.18            np111py36_blas_openblas_203  conda-forge     [blas_openblas]
#                           .  0.18            np112py27_blas_openblas_204  conda-forge     [blas_openblas]
#                           .  0.18            np112py35_blas_openblas_204  conda-forge     [blas_openblas]
#                           .  0.18            np112py36_blas_openblas_204  conda-forge     [blas_openblas]
#                              0.18.1              np111py27_0  defaults
#                              0.18.1          np111py27_nomkl_0  defaults        [nomkl]
#                              0.18.1              np111py34_0  defaults
#                              0.18.1          np111py34_nomkl_0  defaults        [nomkl]
#                              0.18.1              np111py35_0  defaults
#                              0.18.1          np111py35_nomkl_0  defaults        [nomkl]
#                              0.18.1              np111py36_0  defaults
#                              0.18.1          np111py36_nomkl_0  defaults        [nomkl]
#                              0.18.1              np111py27_1  defaults
#                              0.18.1          np111py27_nomkl_1  defaults        [nomkl]
#                              0.18.1              np111py34_1  defaults
#                              0.18.1          np111py34_nomkl_1  defaults        [nomkl]
#                              0.18.1              np111py35_1  defaults
#                              0.18.1          np111py35_nomkl_1  defaults        [nomkl]
#                              0.18.1              np111py36_1  defaults
#                              0.18.1          np111py36_nomkl_1  defaults        [nomkl]
#                              0.18.1              np112py27_1  defaults
#                              0.18.1          np112py27_nomkl_1  defaults        [nomkl]
#                           .  0.18.1              np112py35_1  defaults
#                              0.18.1          np112py35_nomkl_1  defaults        [nomkl]
#                              0.18.1              np112py36_1  defaults
#                              0.18.1          np112py36_nomkl_1  defaults        [nomkl]

# %% [markdown]
# Let's go for an older version, 0.17:

# %%
# !conda install -y -q -n python27 scikit-learn=0.17
# Out:
# Fetching package metadata ...........
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/yoavram/miniconda3/envs/python27:
#
# The following NEW packages will be INSTALLED:
#
#     scikit-learn: 0.17.1-np111py27_blas_openblas_202 conda-forge [blas_openblas]
#
# The following packages will be DOWNGRADED due to dependency conflicts:
#
#     numpy:        1.12.0-py27_blas_openblas_200      conda-forge [blas_openblas] --> 1.11.2-py27_blas_openblas_201      conda-forge [blas_openblas]
#     openblas:     0.2.19-1                           conda-forge --> 0.2.18-6                           conda-forge
#     scipy:        0.19.0-np112py27_blas_openblas_200 conda-forge [blas_openblas] --> 0.18.1-np111py27_blas_openblas_200 conda-forge [blas_openblas]

# %% [markdown]
# This required downgrading NumPy and SciPy, because earlier versions of these packages were requirements for Scikit-learn 0.17.1.
#
# Of course we can upgrade to latest versions with: `conda update numpy scipy` if we are sure it won't break Scikit-learn.
#
# We can remove an environment with
#
# ```
# conda env remove -n <env-name>
# ```
#
# and also write all the environment details to a file with:

# %%
# !conda env export -n python27 > environment_py27.yml
# Out:
# DEPRECATION: The default format will switch to columns in the future. You can use --format=(legacy|columns) (or define a format=(legacy|columns) in your pip.conf under the [list] section) to disable this warning.

# %%
# %less environment_py27.yml

# %% [markdown]
# We can then install an environment using this file with `conda env create -n <env-name> -f environment_py27.yml`.

# %% [markdown]
# # References
#
# - [Managing environments with conda](http://conda.pydata.org/docs/using/envs.html)
# - Slides: [Packaging and deployment with conda](https://speakerdeck.com/teoliphant/packaging-and-deployment-with-conda) by Travis Oliphant.
# - [Conda: Myths and Misconceptions](http://jakevdp.github.io/blog/2016/08/25/conda-myths-and-misconceptions/) by Jake VanderPlas.

# %% [markdown]
# ## Colophon
# This notebook was written by [Yoav Ram](http://python.yoavram.com) and is part of the [_Python for Engineers_](https://github.com/yoavram/Py4Eng) course.
#
# The notebook was written using [Python](http://python.org/) 3.6.1.
# Dependencies listed in [environment.yml](../environment.yml), full versions in [environment_full.yml](../environment_full.yml).
#
# This work is licensed under a CC BY-NC-SA 4.0 International License.
#
# ![Python logo](https://www.python.org/static/community_logos/python-logo.png)
